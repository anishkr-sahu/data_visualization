# %% [markdown]
# <a href="https://colab.research.google.com/github/anishkr-sahu/data_visualization/blob/main/Revision_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/Iris_neo.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.shape
# Out:
# (150, 6)

# %%
data.size
# Out:
# 900

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  146 non-null    float64
#  2   SepalWidthCm   148 non-null    float64
#  3   PetalLengthCm  146 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     146.000000    148.000000     146.000000    150.000000
# mean    75.500000       5.865753      3.050676       3.798630      1.198667
# std     43.445368       0.821977      0.434952       1.758996      0.763161
# min      1.000000       4.400000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.400000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# data cleaning
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    4
# SepalWidthCm     2
# PetalLengthCm    4
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data['SepalLengthCm'] = data['SepalWidthCm'].fillna(data['SepalLengthCm'].mean())
data['SepalWidthCm'] = data['SepalWidthCm'].fillna(data['SepalWidthCm'].mean())
data['PetalLengthCm'] = data['PetalLengthCm'].fillna(data['PetalLengthCm'].mean())
data['PetalWidthCm'] = data['PetalWidthCm'].fillna(data['PetalWidthCm'].mean())

# %%
data.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            3.5           3.5            1.4           0.2
# 1      2            3.0           3.0            1.4           0.2
# 2      3            3.2           3.2            1.3           0.2
# 3      4            3.1           3.1            1.5           0.2
# 4      5            3.6           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x1 = data[data['SepalLengthCm'] <5.5]
x1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            3.5           3.5            1.4           0.2
# 1      2            3.0           3.0            1.4           0.2
# 2      3            3.2           3.2            1.3           0.2
# 3      4            3.1           3.1            1.5           0.2
# 4      5            3.6           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x2 = data[data['Species'] != 'Iris-setosa']

# %%
x2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            3.2           3.2            4.7           1.4
# 51    52            3.2           3.2            4.5           1.5
# 52    53            3.1           3.1            4.9           1.5
# 53    54            2.3           2.3            4.0           1.3
# 54    55            2.8           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
x3 = data[data['Species'].isin(['Iris-versicolor','Iris-virginica'])]

# %%
x3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            3.2           3.2            4.7           1.4
# 51    52            3.2           3.2            4.5           1.5
# 52    53            3.1           3.1            4.9           1.5
# 53    54            2.3           2.3            4.0           1.3
# 54    55            2.8           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
# data visualization
import matplotlib.pyplot as plt

# %%
# line plot : It tells the trends of the data
plt.plot(data['SepalLengthCm'])
plt.title("line plot")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot(data['SepalWidthCm'])
plt.title('Line plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot(data['Species'])
plt.title('Line plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.scatter(data['SepalLengthCm'],data['SepalWidthCm'])
plt.title('scatter plot')
plt.xlabel('sepalLengthcm')
plt.ylabel('sepalwidthcm')
plt.show()

# %%
plt.scatter(data['PetalLengthCm'],data['PetalWidthCm'])
plt.title('scatter plot')
plt.xlabel('petalLengthcm')
plt.ylabel('petalWidthcm')
plt.show()

# %%
plt.scatter(data['PetalLengthCm'], data['Species'])
plt.title('scatter plot')
plt.xlabel('petalLengthcm')
plt.ylabel('species')
plt.show()

# %%
plt.hist(data['PetalLengthCm'],bins=20)
plt.title('histogram')
plt.xlabel('petalLengthcm')
plt.ylabel('count')
plt.show()

# %%
plt.hist(data['Species'],bins=20)
plt.title('histogram')
plt.xlabel('species')
plt.ylabel('count')
plt.show()

# %%
data['Species'].value_counts().plot(kind='pie',autopct='%0.2f%%')
plt.title('pie chart')
plt.show()

# %%
data['Species'].value_counts().plot(kind='bar')
plt.title('bar chart')
plt.xlabel('species')
plt.ylabel('count')
plt.show()

# %%
plt.boxplot(data['SepalLengthCm'])
plt.title('boxplot')
plt.ylabel('sepalLengthcm')
plt.show()

# %%
data.iloc[:,1:5].plot(kind='box')
plt.title("box plot")
plt.show()

# %%
# seaborn library
import seaborn as sns

# %%
# relational
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',hue='Species',data=data)   # relationships between numerical variables
plt.show()

# %%
sns.lineplot(x="SepalLengthCm", y="PetalLengthCm",data=data) # showing trends
plt.show()

# %%
# distribution
sns.histplot(data['SepalLengthCm'], kde=True)   # visualizing frequency, data spreadness and distribution
plt.show()

# %%
sns.kdeplot(data['SepalLengthCm'])
plt.show()

# %%
sns.displot(data['SepalLengthCm'])
plt.show()

# %%
# categorical data
sns.boxplot(x='Species',y='PetalLengthCm',data=data)
plt.show()

# %%
sns.violinplot(x='Species',y='PetalLengthCm',data=data)
plt.show()

# %%
sns.countplot(x='Species',data=data)
plt.show()

# %%
sns.barplot(x='Species',y='PetalLengthCm',data=data)
plt.show()

# %%
sns.heatmap(data.iloc[:,1:5].corr(), annot=True,cmap='coolwarm')
plt.title('Heatmap')
plt.show()

# %%
sns.pairplot(data,hue='Species')
plt.show()

# %%
# feature engineering
# creating of new column
data['PetalAreaCm'] = data['PetalLengthCm']*data['PetalWidthCm']
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            3.5           3.5            1.4           0.2  Iris-setosa
# 1   2            3.0           3.0            1.4           0.2  Iris-setosa
# 2   3            3.2           3.2            1.3           0.2  Iris-setosa
# 3   4            3.1           3.1            1.5           0.2  Iris-setosa
# 4   5            3.6           3.6            1.4           0.2  Iris-setosa
#
#    PetalAreaCm
# 0         0.28
# 1         0.28
# 2         0.26
# 3         0.30
# 4         0.28

# %%
data['SepalAreaCm'] = data['SepalLengthCm']*data['SepalWidthCm']
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            3.5           3.5            1.4           0.2  Iris-setosa
# 1   2            3.0           3.0            1.4           0.2  Iris-setosa
# 2   3            3.2           3.2            1.3           0.2  Iris-setosa
# 3   4            3.1           3.1            1.5           0.2  Iris-setosa
# 4   5            3.6           3.6            1.4           0.2  Iris-setosa
#
#    PetalAreaCm  SepalAreaCm
# 0         0.28        12.25
# 1         0.28         9.00
# 2         0.26        10.24
# 3         0.30         9.61
# 4         0.28        12.96

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'PetalAreaCm', 'SepalAreaCm'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# PetalAreaCm      0
# SepalAreaCm      0
# dtype: int64

# %%
data['PetalLengthGroupCm'] = pd.cut(data['PetalLengthCm'], bins=[0,2.5,5,7], labels=['small','medium','large'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            3.5           3.5            1.4           0.2  Iris-setosa
# 1   2            3.0           3.0            1.4           0.2  Iris-setosa
# 2   3            3.2           3.2            1.3           0.2  Iris-setosa
# 3   4            3.1           3.1            1.5           0.2  Iris-setosa
# 4   5            3.6           3.6            1.4           0.2  Iris-setosa
#
#    PetalAreaCm  SepalAreaCm PetalLengthGroupCm
# 0         0.28        12.25              small
# 1         0.28         9.00              small
# 2         0.26        10.24              small
# 3         0.30         9.61              small
# 4         0.28        12.96              small

# %%
data['SepalLengthGroupCm'] = pd.cut(data['SepalLengthCm'], bins=[0,2.5,5,7], labels=['small','medium','large'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            3.5           3.5            1.4           0.2  Iris-setosa
# 1   2            3.0           3.0            1.4           0.2  Iris-setosa
# 2   3            3.2           3.2            1.3           0.2  Iris-setosa
# 3   4            3.1           3.1            1.5           0.2  Iris-setosa
# 4   5            3.6           3.6            1.4           0.2  Iris-setosa
#
#    PetalAreaCm  SepalAreaCm PetalLengthGroupCm SepalLengthGroupCm
# 0         0.28        12.25              small             medium
# 1         0.28         9.00              small             medium
# 2         0.26        10.24              small             medium
# 3         0.30         9.61              small             medium
# 4         0.28        12.96              small             medium

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['species_encoded'] = le.fit_transform(data['Species'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            3.5           3.5            1.4           0.2  Iris-setosa
# 1   2            3.0           3.0            1.4           0.2  Iris-setosa
# 2   3            3.2           3.2            1.3           0.2  Iris-setosa
# 3   4            3.1           3.1            1.5           0.2  Iris-setosa
# 4   5            3.6           3.6            1.4           0.2  Iris-setosa
#
#    PetalAreaCm  SepalAreaCm PetalLengthGroupCm SepalLengthGroupCm  \
# 0         0.28        12.25              small             medium
# 1         0.28         9.00              small             medium
# 2         0.26        10.24              small             medium
# 3         0.30         9.61              small             medium
# 4         0.28        12.96              small             medium
#
#    species_encoded
# 0                0
# 1                0
# 2                0
# 3                0
# ...

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#             Species  PetalAreaCm  SepalAreaCm PetalLengthGroupCm  \
# 145  Iris-virginica        11.96         9.00              large
# 146  Iris-virginica         9.50         6.25             medium
# 147  Iris-virginica        10.40         9.00              large
# 148  Iris-virginica        12.42        11.56              large
# 149  Iris-virginica         9.18         9.00              large
#
#     SepalLengthGroupCm  species_encoded
# 145             medium                2
# 146              small                2
# 147             medium                2
# ...

# %%
data = pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  PetalAreaCm  \
# 0   1            3.5           3.5            1.4           0.2         0.28
# 1   2            3.0           3.0            1.4           0.2         0.28
# 2   3            3.2           3.2            1.3           0.2         0.26
# 3   4            3.1           3.1            1.5           0.2         0.30
# 4   5            3.6           3.6            1.4           0.2         0.28
#
#    SepalAreaCm  species_encoded  Species_Iris-versicolor  \
# 0        12.25                0                    False
# 1         9.00                0                    False
# 2        10.24                0                    False
# 3         9.61                0                    False
# 4        12.96                0                    False
#
#    Species_Iris-virginica  PetalLengthGroupCm_medium  \
# 0                   False                      False
# ...

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            3.0           3.0            5.2           2.3
# 146  147            2.5           2.5            5.0           1.9
# 147  148            3.0           3.0            5.2           2.0
# 148  149            3.4           3.4            5.4           2.3
# 149  150            3.0           3.0            5.1           1.8
#
#      PetalAreaCm  SepalAreaCm  species_encoded  Species_Iris-versicolor  \
# 145        11.96         9.00                2                    False
# 146         9.50         6.25                2                    False
# 147        10.40         9.00                2                    False
# 148        12.42        11.56                2                    False
# 149         9.18         9.00                2                    False
#
#      Species_Iris-virginica  PetalLengthGroupCm_medium  \
# 145                    True                      False
# ...
